# %%
##plot trade-off between H-Vp for seismic phase Ps, PmP and SmS asumming Vp to be constant
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
plt.rcParams.update({"font.size":7})
plt.rcParams['figure.dpi'] = 120
fig = plt.figure(figsize=(12/2.54,15/2.54))
rayp=0.08

# true sedimentary parameters
Vs = 1.5
kk=2.5
Vp = Vs*kk
H = 5
##sedimentary H-Vp
ax = fig.add_subplot(321)

TPbs = H*(np.sqrt(1/Vs**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
TPpPbs = H*(np.sqrt(1/Vs**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
TPbP = 2*H*np.sqrt(1/Vp**2-rayp**2)
TSbS = 2*H*np.sqrt(1/Vs**2-rayp**2)
# print(TPs,TPmP,TSmS)

Ks = np.linspace(1.5,3.0,101)
Hs_Pbs = TPbs/(np.sqrt(Ks**2/Vp**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
Hs_PpPbs = TPpPbs/(np.sqrt(Ks**2/Vp**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
Hs_SbS = TSbS/np.sqrt(Ks**2/Vp**2-rayp**2)/2
Hs_PbP = np.ones(Ks.shape)*H
ax.plot(Hs_Pbs,Ks,lw=2,color='darkred',label='Ps')
ax.plot(Hs_PpPbs,Ks,lw=1,color='darkcyan',label='PpPs/SP')
ax.plot(Hs_PbP,Ks,lw=2,color='mediumblue',label='PP')
ax.plot(Hs_SbS,Ks,lw=1,color='darkorange',label='PpSs/SS')
ax.set_xlim(0,10)
xmin,xmax = ax.get_xlim()
ymin,ymax = ax.get_ylim()
ax.text(xmin,ymax,"(a) Sediments",ha="left",va="bottom",fontsize=8)
ax.set_xlabel("H [km]")
ax.set_ylabel('Vp/Vs')


##sedimentary H-Vp
ax = fig.add_subplot(323)

TPs = H*(np.sqrt(1/Vs**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
TPpPs = H*(np.sqrt(1/Vs**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
TPmP = 2*H*np.sqrt(1/Vp**2-rayp**2)
TSmS = 2*H*np.sqrt(1/Vs**2-rayp**2)
Vps = np.linspace(2,5,51)
Hs_Ps = TPs/(np.sqrt(kk**2/Vps**2-rayp**2)-np.sqrt(1/Vps**2-rayp**2))
Hs_PpPs = TPpPs/(np.sqrt(kk**2/Vps**2-rayp**2)+np.sqrt(1/Vps**2-rayp**2))
Hs_SmS = TSmS/np.sqrt(kk**2/Vps**2-rayp**2)/2
Hs_PmP = TPmP/np.sqrt(1/Vps**2-rayp**2)/2
ax.plot(Hs_Ps,Vps,lw=2,color='darkred')
ax.plot(Hs_PpPs,Vps,lw=1,color='darkcyan')
ax.plot(Hs_PmP,Vps,lw=2,color='mediumblue')
ax.plot(Hs_SmS,Vps,lw=1,color='darkorange')
xmin,xmax = ax.get_xlim()
ymin,ymax = ax.get_ylim()
ax.text(xmin,ymax,"(c)",ha="left",va="bottom",fontsize=8)
ax.set_xlabel("H [km]")
ax.set_ylabel('Vp [km/s]')

##sedimentary Vp/Vs-Vp
ax = fig.add_subplot(325)
TPms = H*(np.sqrt(1/Vs**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
TPpPms = H*(np.sqrt(1/Vs**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
TPmP = 2*H*np.sqrt(1/Vp**2-rayp**2)
TSmS = 2*H*np.sqrt(1/Vs**2-rayp**2)
Vps = np.linspace(2,5,51)
Ks_Pms = np.sqrt(((TPms/H+np.sqrt(1/Vps**2-rayp**2))**2+rayp**2)*Vps**2)
Ks_PpPms = np.sqrt(((TPpPms/H-np.sqrt(1/Vps**2-rayp**2))**2+rayp**2)*Vps**2)
# Ks_PmP = np.sqrt(((TPs/Hs_Ps+np.sqrt(1/Vps**2-rayp**2))**2+rayp**2)*Vps**2)
Ks_SmS = np.sqrt(((TSmS/H/2)**2+rayp**2)*Vps**2)
ax.plot(Ks_Pms,Vps,lw=2,color='darkred')
ax.plot(Ks_PpPms,Vps,lw=1,color='darkcyan')
# ax.plot(Hs_PmP,Vps,lw=0.5,color='blue',label='PmP')
ax.plot(Ks_SmS,Vps,lw=1,color='darkorange')
xmin,xmax = ax.get_xlim()
ymin,ymax = ax.get_ylim()
ax.text(xmin,ymax,"(e)",ha="left",va="bottom",fontsize=8)
ax.set_xlabel("Vp/Vs")
ax.set_ylabel('Vp [km/s]')



# true sedimentary parameters
Vs = 3.65
kk=1.78
Vp = Vs*kk
H = 40
##sedimentary H-Vp
ax = fig.add_subplot(322)

TPbs = H*(np.sqrt(1/Vs**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
TPpPbs = H*(np.sqrt(1/Vs**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
TPbP = 2*H*np.sqrt(1/Vp**2-rayp**2)
TSbS = 2*H*np.sqrt(1/Vs**2-rayp**2)
# print(TPs,TPmP,TSmS)

Ks = np.linspace(1.5,2.0,101)
Hs_Pbs = TPbs/(np.sqrt(Ks**2/Vp**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
Hs_PpPbs = TPpPbs/(np.sqrt(Ks**2/Vp**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
Hs_SbS = TSbS/np.sqrt(Ks**2/Vp**2-rayp**2)/2
Hs_PbP = np.ones(Ks.shape)*H
ax.plot(Hs_Pbs,Ks,lw=2,color='darkred')
ax.plot(Hs_PpPbs,Ks,lw=1,color='darkcyan')
ax.plot(Hs_PbP,Ks,lw=2,color='mediumblue')
ax.plot(Hs_SbS,Ks,lw=1,color='darkorange')
xmin,xmax = ax.get_xlim()
ymin,ymax = ax.get_ylim()
ax.text(xmin,ymax,"(b) Crust",ha="left",va="bottom",fontsize=8)
ax.set_xlim(30,50)
ax.set_xlabel("H [km]")
ax.set_ylabel('Vp/Vs')


##sedimentary H-Vp
ax = fig.add_subplot(324)

TPs = H*(np.sqrt(1/Vs**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
TPpPs = H*(np.sqrt(1/Vs**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
TPmP = 2*H*np.sqrt(1/Vp**2-rayp**2)
TSmS = 2*H*np.sqrt(1/Vs**2-rayp**2)
Vps = np.linspace(5,7,51)
Hs_Ps = TPs/(np.sqrt(kk**2/Vps**2-rayp**2)-np.sqrt(1/Vps**2-rayp**2))
Hs_PpPs = TPpPs/(np.sqrt(kk**2/Vps**2-rayp**2)+np.sqrt(1/Vps**2-rayp**2))
Hs_SmS = TSmS/np.sqrt(kk**2/Vps**2-rayp**2)/2
Hs_PmP = TPmP/np.sqrt(1/Vps**2-rayp**2)/2
ax.plot(Hs_Ps,Vps,lw=2,color='darkred')
ax.plot(Hs_PpPs,Vps,lw=1,color='darkcyan')
ax.plot(Hs_PmP,Vps,lw=2,color='mediumblue')
ax.plot(Hs_SmS,Vps,lw=1,color='darkorange')
xmin,xmax = ax.get_xlim()
ymin,ymax = ax.get_ylim()
ax.text(xmin,ymax,"(d)",ha="left",va="bottom",fontsize=8)
ax.set_xlim(30,50)
ax.set_xlabel("H [km]")
ax.set_ylabel('Vp [km/s]')

##sedimentary Vp/Vs-Vp
ax = fig.add_subplot(326)
TPms = H*(np.sqrt(1/Vs**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
TPpPms = H*(np.sqrt(1/Vs**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
TPmP = 2*H*np.sqrt(1/Vp**2-rayp**2)
TSmS = 2*H*np.sqrt(1/Vs**2-rayp**2)
Vps = np.linspace(5,7,51)
Ks_Pms = np.sqrt(((TPms/H+np.sqrt(1/Vps**2-rayp**2))**2+rayp**2)*Vps**2)
Ks_PpPms = np.sqrt(((TPpPms/H-np.sqrt(1/Vps**2-rayp**2))**2+rayp**2)*Vps**2)
# Ks_PmP = np.sqrt(((TPs/Hs_Ps+np.sqrt(1/Vps**2-rayp**2))**2+rayp**2)*Vps**2)
Ks_SmS = np.sqrt(((TSmS/H/2)**2+rayp**2)*Vps**2)
ax.plot(Ks_Pms,Vps,lw=2,color='darkred')
ax.plot(Ks_PpPms,Vps,lw=1,color='darkcyan')
# ax.plot(Hs_PmP,Vps,lw=0.5,color='blue',label='PmP')
ax.plot(Ks_SmS,Vps,lw=1,color='darkorange')
xmin,xmax = ax.get_xlim()
ymin,ymax = ax.get_ylim()
ax.text(xmin,ymax,"(f)",ha="left",va="bottom",fontsize=8)
ax.set_xlabel("Vp/Vs")
ax.set_ylabel('Vp [km/s]')


fig.legend(loc='upper center',	bbox_to_anchor=(0.5, 0),ncol=2)
plt.tight_layout()
plt.show()

# %%
##plot trade-off between H-Vp for seismic phase Ps, PmP and SmS asumming Vp to be constant
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
zhfont1 = FontProperties(fname='/usr/share/fonts/font/simhei.ttf', size=10)
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)



Vs = 3.65
kk = 1.78
Vp = Vs*kk
H = 40

rayp=0.08
TPs = H*(np.sqrt(1/Vs**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
TPpPs = H*(np.sqrt(1/Vs**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
TPmP = 2*H*np.sqrt(1/Vp**2-rayp**2)
TSmS = 2*H*np.sqrt(1/Vs**2-rayp**2)


Vps = np.linspace(5,7,51)
Hs_Ps = TPs/(np.sqrt(kk**2/Vps**2-rayp**2)-np.sqrt(1/Vps**2-rayp**2))
Hs_PpPs = TPpPs/(np.sqrt(kk**2/Vps**2-rayp**2)+np.sqrt(1/Vps**2-rayp**2))
Hs_SmS = TSmS/np.sqrt(kk**2/Vps**2-rayp**2)/2
Hs_PmP = TPmP/np.sqrt(1/Vps**2-rayp**2)/2


ax.plot(Hs_Ps,Vps,lw=0.5,color='red',label='Pms')
ax.plot(Hs_PpPs,Vps,lw=0.5,color='pink',label='PmpPms')
ax.plot(Hs_PmP,Vps,lw=0.5,color='blue',label='PmP')
ax.plot(Hs_SmS,Vps,lw=0.5,color='cyan',label='SmS')



ax.legend()

ax.set_xlabel("H [km]")
ax.set_ylabel('Vp [km/s]')
plt.show()

# %%
##plot trade-off between Vp/Vs-Vp for seismic phase Ps, PmP and SmS asumming Vp to be constant
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
zhfont1 = FontProperties(fname='/usr/share/fonts/font/simhei.ttf', size=10)
Vs = 3.65
kk = 1.78
Vp = Vs*kk
H = 40

rayp=0.06
TPms = H*(np.sqrt(1/Vs**2-rayp**2)-np.sqrt(1/Vp**2-rayp**2))
TPpPms = H*(np.sqrt(1/Vs**2-rayp**2)+np.sqrt(1/Vp**2-rayp**2))
TPmP = 2*H*np.sqrt(1/Vp**2-rayp**2)
TSmS = 2*H*np.sqrt(1/Vs**2-rayp**2)
print(TPs,TPmP,TSmS)

Vps = np.linspace(5.5,7,51)
Ks_Pms = np.sqrt(((TPms/H+np.sqrt(1/Vps**2-rayp**2))**2+rayp**2)*Vps**2)
Ks_PpPms = np.sqrt(((TPpPms/H-np.sqrt(1/Vps**2-rayp**2))**2+rayp**2)*Vps**2)
# Ks_PmP = np.sqrt(((TPs/Hs_Ps+np.sqrt(1/Vps**2-rayp**2))**2+rayp**2)*Vps**2)
Ks_SmS = np.sqrt(((TSmS/H/2)**2+rayp**2)*Vps**2)

plt.close("all")
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.plot(Ks_Pms,Vps,lw=0.5,color='red',label='Pms')
ax.plot(Ks_PpPms,Vps,lw=0.5,color='pink',label='PpPms')
# ax.plot(Hs_PmP,Vps,lw=0.5,color='blue',label='PmP')
ax.plot(Ks_SmS,Vps,lw=0.5,color='cyan',label='SmS')
ax.legend()
ax.set_xlabel("Vp/Vs")
ax.set_ylabel('Vp [km/s]')
plt.show()
# Out:
# 5.023236422888847 11.339277483183652 21.385750328961347
