# %%
##plot Hk figures
from HkVp_multilayer.plotting import Plot_HkVp
import matplotlib.pyplot as plt 
import numpy as np 

save_filename = f"Hk_result_52_10_Hk_result.npz"
resultdir = f"synthetic_data_S1.0/Varyp_2sediment_crust_mantle_synthetics_c35_d1s5_k2s1.8_dt0.01_G2/sediments_depth5"
plot_instance = Plot_HkVp(savefile=f"{resultdir}/{save_filename}")
plot_instance.data_Hk_Phasefitting(savefile=f"{resultdir}/Hk_phasefitting.png",dpi=600,plotlengths = [20,25,20,25,20,25])
# Out:
# Pbs  and  PsSis  are overlapped
# 4.1016834617658375 2.7559234260515453 11.535572850803916 10.189812815089631
